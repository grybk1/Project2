# %%
import psycopg2

# %%
connection = psycopg2.connect(user = "postgres",
                                  password = "postgres",
                                  host = "127.0.0.1",
                                  port = "5432",
                                  database = "monsters")

cursor = connection.cursor()
    # Print PostgreSQL Connection properties
print ( connection.get_dsn_parameters(),"\n")

    # Print PostgreSQL version
cursor.execute("SELECT version();")
record = cursor.fetchone()
print("You are connected to - ", record,"\n")
# Out:
# {'user': 'postgres', 'dbname': 'monsters', 'host': '127.0.0.1', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 12.1, compiled by Visual C++ build 1914, 64-bit',)

# %%
cursor.execute("select * from public.movies")
cursor.fetchall()
# Out:
# [(0, 'The 8th Plague', 'Franklin Guerrero Jr.', 2006, 'USA'),
#  (1, '13 Eerie', 'Lowell Dean', 2013, 'Canada'),
#  (2, '28 Days Later...', 'Danny Boyle', 2002, 'UK, Spain'),
#  (3, '28 Weeks Later', 'Juan Carlos Fresnadillo', 2007, 'UK, Spain'),
#  (4, 'Abraham Lincoln vs. Zombies', 'Richard Schenkman', 2012, 'USA'),
#  (5, 'After Sundown', 'Christopher Abram, Michael W. Brown', 2006, 'USA'),
#  (6, 'The Alien Dead', 'Fred Olen Ray', 1980, 'USA'),
#  (7, "All Souls' Day", 'Alan Gilsenan', 1997, 'Ireland'),
#  (8, 'Alone', 'Çagan Irmak', 2008, 'Turkey'),
#  (9, 'Alone', 'Çagan Irmak', 2008, 'Turkey'),
#  (10,
#   'The Amazing Adventures of the Living Corpse',
#   'Justin Paul Ritter',
#   2012,
#   'USA'),
#  (11, 'American Zombie', 'Grace Lee', 2007, 'USA, South Korea'),
#  (12, 'Anger of the Dead', 'Francesco Picone', 2013, 'Italy'),
#  (13, 'Anna and the Apocalypse', 'John McPhail', 2017, 'UK'),
#  (14, 'April Apocalypse', 'Jarret Tarnol', 2013, 'USA'),
#  (15, 'The Astro-Zombies', 'Ted V. Mikels', 1968, 'USA'),
#  (16, 'Automaton Transfusion', 'Steven C. Miller', 2006, 'USA'),
#  (17, 'Autumn', 'Özcan Alper', 2008, 'Turkey, Germany'),
#  (18, 'Baron Blood', 'Mario Bava', 1972, 'Italy, West Germany, USA'),
#  (19, 'Bath Salt Zombies', 'Dustin Mills', 2013, 'USA'),
#  (20, 'The Battery', 'Jeremy Gardner', 2012, 'USA'),
#  (21, 'Battle of the Damned', 'Christopher Hatton', 2013, 'USA, Singapore'),
#  (22, 'Battlefield Baseball', 'Yudai Yamaguchi', 2003, 'Japan'),
#  (23, 'Before Dawn', 'Dominic Brunt', 2013, 'UK'),
#  (24, 'Beneath Still Waters', 'Brian Yuzna', 2005, 'Spain, UK'),
#  (25, 'Beneath the Surface', 'Daniel Fridell', 1997, 'Sweden'),
#  (26, 'Beverly Hills Bodysnatchers', 'Jonathan Mostow', 1989, 'USA'),
#  (27, 'Beverly Lane', 'Joshua Hull', 2010, 'USA'),
#  (28, 'The Beyond', 'Lucio Fulci', 1981, 'Italy'),
#  (29, 'Beyond Re-Animator', 'Brian Yuzna', 2003, 'Spain, USA'),
#  (30, 'Bio-Zombie', 'Wilson Yip', 1998, 'Hong Kong'),
#  (31, 'Biohazardous', 'Michael J. Hein', 2001, 'USA'),
#  (32, 'Black Demons', 'Umberto Lenzi', 1991, 'Italy'),
#  (33, 'Black Magic 2', 'N/A', 1994, 'USA'),
#  (34, 'Black Sheep', 'Jonathan King', 2006, 'New Zealand'),
#  (35, 'Black Swarm', 'David Winning', 2007, 'Canada'),
#  (36, 'Bled White', 'Jose Carlos Gomez', 2009, 'USA'),
#  (37, 'Block Z', 'Mikhail Red', 2020, 'Philippines'),
#  (38, 'Blood Creek', 'Joel Schumacher', 2009, 'USA'),
#  (39, 'Blood Quantum', 'Jeff Barnaby', 2019, 'Canada'),
#  (40, 'Blood of the Beast', 'Georg Koszulinski', 2003, 'USA'),
#  (41, 'Bone Sickness', 'Brian Paulin', 2004, 'USA'),
#  (42, 'The Boneyard', 'James Cummins', 1991, 'USA'),
#  (43,
#   'The Book of Zombie',
#   'Paul Cranefield, Scott Kragelund, Erik Van Sant',
#   2010,
#   'USA'),
#  (44, 'Bowery at Midnight', 'Wallace Fox', 1942, 'USA'),
#  (45, 'Boy Eats Girl', 'Stephen Bradley', 2005, 'Ireland, UK'),
#  (46, 'Brain Blockers', 'Lincoln Kupchak', 2007, 'USA'),
#  (47, 'Brain Dead', 'Adam Simon', 1990, 'USA'),
#  (48, 'BrainDead', 'N/A', 2016, 'USA'),
#  (49, 'Bride of Re-Animator', 'Brian Yuzna', 1990, 'USA'),
#  (50, 'Broken Springs', 'Neeley Lawson', 2010, 'Italy'),
#  (51, 'Burial Ground: The Nights of Terror', 'Andrea Bianchi', 1981, 'USA'),
#  (52, 'The Burning Dead', 'Rene Perez', 2015, 'USA'),
#  (53, 'Burying the Ex', 'Joe Dante', 2014, 'Australia'),
#  (54, 'Cargo', 'Ben Howling, Yolanda Ramke', 2017, 'USA'),
#  (55, 'The Cabin in the Woods', 'Drew Goddard', 2011, 'USA'),
#  (56, 'Caustic Zombies', 'Johnny Daggers', 2011, 'Italy, France, Germany'),
#  (57, 'Cemetery Man', 'Michele Soavi', 1994, 'USA'),
#  (58, 'Cell', 'Tod Williams', 2016, 'UK'),
#  (59, 'The Children', 'Tom Shankland', 2008, 'USA'),
#  (60, 'Children of the Living Dead', 'Tor Ramsey', 2001, 'USA'),
#  (61,
#   "Children Shouldn't Play with Dead Things",
#   'Bob Clark',
#   1972,
#   'Czech Republic'),
#  (62, 'Choking Hazard', 'Marek Dobes', 2004, 'USA'),
#  (63, 'Chopper Chicks in Zombietown', 'Dan Hoskins', 1989, 'USA'),
#  (64, 'Christmas with the Dead', 'T.L. Lankford', 2012, 'USA'),
#  (65, 'C.H.U.D. II: Bud the Chud', 'David Irving', 1989, 'USA'),
#  (66, 'Cooties', 'Jonathan Milott, Cary Murnion', 2014, 'Italy'),
#  (67, 'City of the Living Dead', 'Lucio Fulci', 1980, 'USA'),
#  (68, 'City of Rott', 'Frank Sudol', 2006, 'UK'),
#  (69, 'Cockneys vs Zombies', 'Matthias Hoene', 2012, 'UK'),
#  (70, 'Colin', 'Marc Price', 2008, 'USA'),
#  (71, 'Collapse', 'Chris Smith', 2009, 'USA'),
#  (72, 'Contracted', 'Eric England', 2013, 'USA'),
#  (73, 'Contracted: Phase II', 'Josh Forbes', 2015, 'USA'),
#  (74, 'Corpses Are Forever', 'Jose Prendes', 2004, 'USA'),
#  (75, 'Creature with the Atom Brain', 'Edward L. Cahn', 1955, 'USA'),
#  (76, 'Creepshow', 'George A. Romero', 1982, 'USA'),
#  (77, 'The Crypt', 'Craig McMahon', 2009, 'Ireland, France'),
#  (78, 'The Cured', 'David Freyne', 2017, 'USA'),
#  (79, 'Evil Grave: Curse of the Maya', 'David Heavener', 2004, 'USA'),
#  (80, 'Dance of the Dead', 'Gregg Bishop', 2008, 'Finland, Iceland'),
#  (81, 'Dark Floors', 'Pete Riski, Alan Smithee', 2008, 'USA'),
#  (82, 'Dark Harvest', 'Paul Moore', 2004, 'USA, Canada, Japan, France'),
#  (83, 'Dawn of the Dead', 'Zack Snyder', 2004, 'USA, Canada, Japan, France'),
#  (84, 'Dawn of the Dead', 'Zack Snyder', 2004, 'USA'),
#  (85, 'Dawn of the Mummy', 'Frank Agrama', 1981, 'USA'),
#  (86, 'Day of the Dead', 'George A. Romero', 1985, 'USA'),
#  (87, 'Day of the Dead', 'George A. Romero', 1985, 'USA'),
#  (88,
#   'Day of the Dead 2: Contagium',
#   'Ana Clavell, James Glenn Dudelson',
#   2005,
#   'Bulgaria, USA'),
#  (89,
#   'Day of the Dead: Bloodline',
#   'Hèctor Hernández Vicens',
#   2017,
#   'Canada, France'),
#  (90, 'Days of Darkness', 'Denys Arcand', 2007, 'UK'),
#  (91, 'The Dead', 'Howard J. Ford & Jonathan Ford', 2010, 'UK'),
#  (92, 'The Dead 2: India', 'Howard J. Ford & Jonathan Ford', 2013, 'USA'),
#  (93, 'Dead 7', 'Danny Roew', 2016, 'USA'),
#  (94, 'Dead Air', 'Corbin Bernsen', 2009, 'USA'),
#  (95,
#   "Pirates of the Caribbean: Dead Man's Chest",
#   'Gore Verbinski',
#   2006,
#   'USA'),
#  (96,
#   "Pirates of the Caribbean: Dead Man's Chest",
#   'Gore Verbinski',
#   2006,
#   'USA'),
#  (97, 'The Dead and the Damned', 'Rene Perez', 2011, 'USA'),
#  (98, 'Dead Before Dawn', 'Charles Correll', 1993, 'USA, Sweden'),
#  (99, "The Dead Don't Die", 'Jim Jarmusch', 2019, 'USA, Thailand'),
#  (100, 'Dead Earth', 'Wych Kaosayananda', 2020, 'USA'),
#  (101, 'The Dead Hate the Living!', 'Dave Parker', 2000, 'USA'),
#  (102, 'Dead Heat', 'Mark Goldblatt', 1988, 'USA'),
#  (103, 'The Dead Inside', 'Travis Betz', 2011, 'Ireland'),
#  (104, 'Dead Meat', 'Conor McMahon', 2004, 'USA'),
#  (105, 'Dead Men Walking', 'Peter Mervis', 2005, 'USA'),
#  (106, 'Dead Moon Rising', 'Mark E. Poole', 2007, 'USA'),
#  (107, 'The Dead Next Door', 'J.R. Bookwalter', 1989, 'USA'),
#  (108, 'The Dead One', 'Brian Cox', 2007, 'Mexico'),
#  (109, 'El muerto', 'Sergio Pérez Grovas', 1991, 'UK'),
#  (110, 'The Dead Outside', 'Kerry Anne Mullaney', 2008, 'USA'),
#  (111, 'The Dead Pit', 'Brett Leonard', 1989, 'USA'),
#  (112, 'Dead Rising: Endgame', 'Pat Williams', 2016, 'USA'),
#  (113, 'Dead Rising: Watchtower', 'Zach Lipovsky', 2015, 'Bahrain'),
#  (114, 'Dead Sands', 'Ameera Al-Qaed', 2013, 'Norway'),
#  (115, 'Dead Snow', 'Tommy Wirkola', 2009, 'USA'),
#  (116, 'Dead Space: Downfall', 'Chuck Patton', 2008, 'USA'),
#  (117, 'Dead Within', 'Kent Green', 2002, 'USA'),
#  (118, 'Deadgirl', 'Marcel Sarmiento & Gadi Harel', 2008, 'USA'),
#  (119, 'Deadheads', 'Brett Pierce, Drew T. Pierce', 2011, 'USA'),
#  (120, 'Deadly Friend', 'Wes Craven', 1986, 'Australia, New Zealand'),
#  (121, 'Death Warmed Up', 'David Blyth', 1984, 'UK, Germany'),
#  (122, 'Deathwatch', 'M.J. Bassett', 2002, 'USA'),
#  (123, 'Decay', 'Joseph Wartnerchaney', 2015, 'USA, Canada'),
#  (124, 'Deep River: The Island', 'Ben Bachelder', 2009, 'Chile'),
#  (125, 'Descendents', 'Jorge Olguín', 2008, 'USA'),
#  (126, 'Detention of the Dead', 'Alex Craig Mann', 2012, 'USA'),
#  (127, "The Devil's Daughter", 'Jeannot Szwarc', 1973, 'UK'),
#  (128, "Devil's Playground", 'Mark McQueen', 2010, 'USA'),
#  (129, 'Diary of the Dead', 'George A. Romero', 2007, 'USA'),
#  (130, 'Die-ner (Get It?)', 'Patrick Horvath', 2009, 'USA'),
#  (131, 'Die You Zombie Bastards!', 'Caleb Emerson', 2005, 'Sweden'),
#  (132, 'Die Zombiejäger', 'Jonas Wolcher', 2005, 'Japan'),
#  (133, 'The Discarnates', 'Nobuhiko Ôbayashi', 1988, 'India'),
#  (134, 'Do Gaz Zameen Ke Neeche', 'Tulsi Ramsay', 1972, 'USA'),
#  (135, 'Doc of the Dead', 'Alexandre O. Philippe', 2014, 'UK'),
#  (136, "Doctor Blood's Coffin", 'Sidney J. Furie', 1961, 'UK'),
#  (137, 'Doghouse', 'Jake West', 2009, 'USA'),
#  (138,
#   "Don't Go in the House",
#   'Joseph Ellison',
#   1979,
#   'UK, Czech Republic, Germany, USA'),
#  (139, 'Doom', 'Andrzej Bartkowiak', 2005, 'USA'),
#  (140, 'Dorm of the Dead', 'Donald Farmer', 2006, 'Mexico'),
#  (141, 'Dr. Satán y la magia negra', 'Rogelio A. González', 1968, 'USA'),
#  (142, 'Dylan Dog: Dead of Night', 'Kevin Munroe', 2010, 'UK'),
#  (143, 'The Earth Dies Screaming', 'Terence Fisher', 1964, 'USA'),
#  (144, 'Eat Me!', 'Katie Carman-Lehach', 2010, 'USA, UK'),
#  (145, 'Ed and His Dead Mother', 'Jonathan Wacks', 1993, 'USA'),
#  (146,
#   'Edges of Darkness',
#   'Blaine Cade, J. Horton',
#   2008,
#   'Germany, Austria'),
#  (147, 'Endzeit', 'Sebastian Fritzsch', 2013, 'Italy'),
#  (148,
#   'Erotic Nights of the Living Dead',
#   "Joe D'Amato",
#   1980,
#   'Sweden, Denmark'),
#  (149, 'Evil', 'Mikael Håfström', 2003, 'USA'),
#  (150, 'Evil Head', 'Doug Sakmann', 2012, 'Greece'),
#  (151, 'Evil - In the Time of Heroes', 'Giorgos Nousias', 2009, 'Canada'),
#  (152, 'Exhumed', 'Brian Clement', 2003, 'Canada'),
#  (153, 'Exit Humanity', 'John Geddes', 2011, 'USA'),
#  (154, 'Extinction', 'Ben Young', 2018, 'USA'),
#  (155, 'Fading of the Cries', 'Steven Maguire', 2008, 'Canada'),
#  (156, 'Fantasy Island', 'N/A', 1977, 'USA'),
#  (157, 'Fido', 'Andrew Currie', 2006, 'UK'),
#  (158, 'FleshEater', 'S. William Hinzman', 1988, 'USA'),
#  (159, 'Flick', 'David Howard', 2008, 'Canada'),
#  (160, 'The Fog', 'John Carpenter', 1980, 'USA'),
#  (161, 'Forest of the Dead', 'Brian Singleton', 2007, 'USA'),
#  (162, 'The Four Skulls of Jonathan Drake', 'Edward L. Cahn', 1959, 'USA'),
#  (163,
#   'Frankenhooker',
#   'Frank Henenlotter',
#   1990,
#   'Netherlands, USA, Czech Republic'),
#  (164, 'Frankenstein Island', 'Jerry Warren', 1981, 'USA'),
#  (165, "Frankenstein's Army", 'Richard Raaphorst', 2013, 'USA'),
#  (166, 'Freaks of Nature', 'Robbie Pickering', 2015, 'USA, UK'),
#  (167, 'The Frozen Dead', 'N/A', 2016, 'USA'),
#  (168, 'Frozen Scream', 'Frank Roach', 1975, 'USA'),
#  (169, 'Gallowwalkers', 'Andrew Goth', 2012, 'Spain'),
#  (170, 'Garden of the Dead', 'John Hayes', 1972, 'USA'),
#  (171, 'The Ghost Breakers', 'George Marshall', 1940, 'UK'),
#  (172, 'The Ghost Galleon', 'Amando de Ossorio', 1974, 'India'),
#  (173, 'The Ghouls', 'Chad Ferrin', 2003, 'France'),
#  (174, 'The Girl with All the Gifts', 'Colm McCarthy', 2016, 'USA'),
#  (175, 'Go Goa Gone', 'Krishna D.K., Raj Nidimoru', 2013, 'USA'),
#  (176,
#   'Goal of the Dead',
#   'Thierry Poiraud, Benjamin Rocher',
#   2014,
#   'South Korea'),
#  (177, 'Gory Gory Hallelujah', 'Sue Corcoran', 2003, 'Spain, Italy'),
#  (178, 'Grave Mistake', 'Shawn Darling', 2008, 'Italy, Spain'),
#  (179, 'The Guard Post', 'Su-chang Kong', 2008, 'USA'),
#  (180, 'The Hanging Woman', 'José Luis Merino', 1973, 'USA'),
#  (181,
#   'Hell of the Living Dead',
#   'Bruno Mattei, Claudio Fragasso',
#   1980,
#   'USA'),
#  (182, 'Here Alone', 'Rod Blackhurst', 2016, 'USA'),
#  (183, 'Hide and Creep', 'Chuck Hartsell, Chance Shirley', 2004, 'France'),
#  (184, 'The Hive', 'David Yarovesky', 2014, 'UK, Spain'),
#  (185, 'Hood of the Living Dead', 'Eduardo Quiroz, Jose Quiroz', 2005, 'USA'),
#  (186, 'The Horde', 'Yannick Dahan, Benjamin Rocher', 2009, 'Spain'),
#  (187, 'Horror Express', 'Eugenio Martín', 1972, 'USA'),
#  (188, 'The Horror of Party Beach', 'Del Tenney', 1964, 'USA'),
#  (189, 'Horror Rises from the Tomb', 'Carlos Aured', 1973, 'Italy'),
#  (190, 'Horrors of War', 'Peter John Ross, John Whitney', 2006, 'USA'),
#  (191, 'Horrorween', 'Joe Estevez', 2011, 'Germany, Canada, USA'),
#  (192, 'The House by the Cemetery', 'Lucio Fulci', 1981, 'USA'),
#  (193, 'House of the Damned', 'Maury Dexter', 1963, 'USA'),
#  (194, 'House of the Dead', 'Uwe Boll', 2003, 'USA'),
#  (195, 'House of the Dead 2', 'Michael Hurst', 2005, 'Japan'),
#  (196, 'The House of Seven Corpses', 'Paul Harrison', 1974, 'USA'),
#  (197, 'Hysterical', 'Chris Bearde', 1983, 'USA'),
#  (198, 'I Am a Hero', 'Shinsuke Sato', 2015, 'USA'),
#  (199, 'I Am Legend', 'Francis Lawrence', 2007, 'UK'),
#  (200, 'I Am Omega', 'Griff Furst', 2007, 'USA'),
#  (201, 'I Eat Your Skin', 'Del Tenney', 1971, 'New Zealand'),
#  (202, 'Inmate Zero', 'Russell Owen', 2020, 'USA'),
#  (203, 'I Sell the Dead', 'Glenn McQuaid', 2008, 'USA'),
#  (204, 'I Survived a Zombie Holocaust', 'Guy Pigden', 2014, 'USA'),
#  (205, 'I Walked with a Zombie', 'Jacques Tourneur', 1943, 'UK'),
#  (206, 'I Was a Teenage Zombie', 'John Elias Michalakis', 1987, 'USA'),
#  (207, 'I Was a Zombie for the F.B.I.', 'Marius Penczner', 1982, 'USA'),
#  (208, 'I Zombie: The Chronicles of Pain', 'Andrew Parkinson', 1998, 'Mexico'),
#  (209,
#   'The Incredibly Strange Creatures Who Stopped Living and Became Mixed-Up Zombies!!?',
#   'Ray Dennis Steckler',
#   1964,
#   'USA'),
#  (210, 'Insanitarium', 'Jeff Buhler', 2008, 'Mexico'),
#  (211,
#   'Blue Demon y Zovek en La invasión de los muertos',
#   'René Cardona',
#   1973,
#   'USA, Canada'),
#  (212, 'Invisible Invaders', 'Edward L. Cahn', 1959, 'Israel'),
#  (213,
#   'Isle of the Snake People',
#   'Juan Ibáñez, Jack Hill',
#   1971,
#   'Spain, Cuba'),
#  (214, 'It Stains the Sands Red', 'Colin Minihan', 2016, 'Japan'),
#  (215, 'Jeruzalem', 'Doron Paz, Yoav Paz', 2015, 'USA'),
#  (216, 'Juan of the Dead', 'Alejandro Brugués', 2011, 'USA'),
#  (217, 'Junk', 'Atsushi Muroga', 2000, 'Japan'),
#  (218, 'Killing Spree', 'Tim Ritter', 1987, 'USA'),
#  (219, 'King of the Zombies', 'Jean Yarbrough', 1941, 'Malaysia'),
#  (220, 'The Kirishima Thing', 'Daihachi Yoshida', 2012, 'Hong Kong'),
#  (221, 'Kiss Daddy Goodbye', 'Patrick Regan', 1981, 'USA, Germany'),
#  (222, 'KL Zombi', 'Ming Jin Woo', 2013, 'France, Canada, USA'),
#  (223, 'Kung Fu Zombie', 'Shan Hua', 1981, 'UK, Ireland'),
#  (224, 'L.A. Zombie', 'Bruce La Bruce', 2010, 'New Zealand'),
#  (225, 'Land of the Dead', 'George A. Romero', 2005, 'UK, Hong Kong'),
#  (226, 'Las momias de Guanajuato', 'N/A', 1962, 'USA'),
#  (227, 'The Last Days on Mars', 'Ruairi Robinson', 2013, 'Spain, Italy'),
#  (228, 'The Last Man on Earth', 'N/A', 2015, 'USA'),
#  (229, 'Last of the Living', 'Logan McMillan', 2009, 'UK, USA'),
#  (230,
#   'The Legend of the 7 Golden Vampires',
#   'Roy Ward Baker, Cheh Chang',
#   1974,
#   'Canada'),
#  (231, 'Legion of the Night', 'Matt Jaissle', 1995, 'USA'),
#  (232, 'Let Sleeping Corpses Lie', 'Jorge Grau', 1974, 'USA'),
#  (233, 'Life After Beth', 'Jeff Baena', 2014, 'USA'),
#  (234, 'Lifeforce', 'Tobe Hooper', 1985, 'Canada'),
#  (235, 'A Little Bit Zombie', 'Casey Walker', 2012, 'USA, Switzerland'),
#  (236, 'Little Monsters', 'Richard Greenberg', 1989, 'USA'),
#  (237, 'Livelihood', 'Ryan Graham', 2005, 'USA'),
#  (238, 'Machine Head', 'Jim Valdez', 2011, 'USA'),
#  (239, 'The Mad', 'John Kalangis', 2007, 'USA'),
#  (240, 'Maggie', 'Henry Hobson', 2015, 'Canada, USA'),
#  (241, 'Make-Out with Violence', 'Deagol Brothers', 2008, 'Canada'),
#  (242, 'Maniac', 'N/A', 2018, 'USA'),
#  (243, 'Maniac Cop', 'William Lustig', 1988, 'Japan'),
#  (244, 'Maniac Cop 2', 'William Lustig', 1990, 'USA'),
#  (245,
#   'Mansion of the Living Dead: The Mansion Jess Built',
#   'Roger Browning',
#   2006,
#   'USA'),
#  (246, 'Meat Market', 'Brian Clement', 2000, 'USA'),
#  (247, 'Meat Market 2', 'Brian Clement', 2001, 'USA'),
#  (248, 'Messiah of Evil', 'Willard Huyck, Gloria Katz', 1973, 'USA'),
#  (249, 'Miss Zombie', 'SABU', 2013, 'France'),
#  (250, 'Monstrosity', 'Joseph V. Mascelli, Jack Pollexfen', 1963, 'USA'),
#  (251, "Jean-Pierr Bouyxou n 'La Morte Vivante'", 'N/A', 2012, 'USA'),
#  (252, 'Mortuary', 'Tobe Hooper', 2005, 'USA'),
#  (253, 'Mulberry Street', 'Ellen Gittelsohn', 1990, 'USA'),
#  (254, 'Mutant', "John 'Bud' Cardos, Mark Rosman", 1984, 'France'),
#  (255, 'Mutants', 'David Morlet', 2009, 'USA'),
#  (256, "My Boyfriend's Back", 'Bob Balaban', 1993, 'USA'),
#  (257, 'Navy Seals vs. Zombies', 'Stanton Barrett', 2015, 'USA'),
#  (258, 'Necropolis Awakened', 'Hudson White', 2002, 'USA'),
#  (259, 'Netherworld', 'David Schmoeller', 1992, 'USA'),
#  (260, 'The Night Eats the World', 'Dominique Rocher', 2018, 'USA'),
#  (261, 'Night Life', 'David Acomba', 1989, 'USA'),
#  (262, 'Night of the Comet', 'Thom Eberhardt', 1984, 'USA'),
#  (263, 'Night of the Creeps', 'Fred Dekker', 1986, 'USA'),
#  (264, 'Night of the Dead', 'Dennis Devine', 2012, 'USA'),
#  (265, 'Night of the Living Dead', 'George A. Romero', 1968, 'USA'),
#  (266, 'Night of the Living Dead', 'George A. Romero', 1968, 'UK'),
#  (267, 'Night of the Living Dead', 'George A. Romero', 1968, 'USA'),
#  (268, 'Night of the Living Dead 3D', 'Jeff Broadstreet', 2006, 'Spain'),
#  (269,
#   'Night of the Living Dead 3D: Re-Animation',
#   'Jeff Broadstreet',
#   2012,
#   'Italy, Spain, Mexico'),
#  (270,
#   'Night of the Living Dead: Darkest Dawn',
#   'Zebediah De Soto, Krisztian Majdik',
#   2015,
#   'USA'),
#  (271, 'Night of the Living Dead: Reanimated', 'Mike Schneider', 2009, 'USA'),
#  (272, 'Night of the Living Dead: Resurrection', 'James Plumb', 2012, 'USA'),
#  (273, 'Night of the Living Deb', 'Kyle Rankin', 2015, 'France, Spain'),
#  (274, 'Night of the Seagulls', 'Amando de Ossorio', 1975, 'Nigeria'),
#  (275, 'The Night Shift', 'N/A', 2014, 'Japan'),
#  (276, 'Nightmare City', 'Umberto Lenzi', 1980, 'USA'),
#  (277, 'Ninjas vs. Zombies', 'Justin Timpane', 2008, 'USA, Hungary'),
#  (278, 'Nixon and Hogan Smoke Christmas', 'Kevin Strange', 2010, 'USA'),
#  (279, 'Nudist Colony of the Dead', 'Mark Pirro', 1991, 'UK'),
#  (280, 'Oasis of the Zombies', 'Jesús Franco', 1982, 'UK'),
#  (281, 'Ojuju', "C.J. 'Fiery' Obasi", 2014, 'UK'),
#  (282, 'One Cut of the Dead', "Shin'ichirô Ueda", 2017, 'USA, Canada'),
#  (283, 'One Dark Night', 'Tom McLoughlin', 1982, 'USA'),
#  (284, 'Open Grave', 'Gonzalo López-Gallego', 2013, 'USA'),
#  (285, 'Ouanga', 'George Terwilliger', 1936, 'USA'),
#  (286, 'Outpost', 'Steve Barker', 2008, 'UK'),
#  (287, 'Outpost: Black Sun', 'Steve Barker', 2012, 'UK'),
#  (288, 'Outpost: Rise of the Spetsnaz', 'Kieran Parker', 2013, 'USA'),
#  (289, 'Overlord', 'Julius Avery', 2018, 'USA'),
#  (290, 'Ozone', 'J.R. Bookwalter', 1995, 'USA'),
#  (291, 'ParaNorman', 'Chris Butler, Sam Fell', 2012, 'USA'),
#  (292, 'Pathogen', 'Emily Hagins', 2006, 'USA'),
#  (293, 'Patient Zero', 'Stefan Ruzowitzky', 2018, 'USA, UK'),
#  (294, 'Peninsula', 'Tim Rolt', 2019, 'Argentina'),
#  (295, 'Pet Sematary', 'Mary Lambert', 1989, 'Argentina'),
#  (296, 'Pet Sematary', 'Mary Lambert', 1989, 'USA'),
#  (297, 'Phantasm', 'Don Coscarelli', 1979, 'UK, USA'),
#  (298, 'Phantasm II', 'Don Coscarelli', 1988, 'USA'),
#  (299, 'Phantasm III: Lord of the Dead', 'Don Coscarelli', 1994, 'USA'),
#  (300,
#   'Pirates of the Caribbean: On Stranger Tides',
#   'Rob Marshall',
#   2011,
#   'USA, Mexico'),
#  (301, 'Plaga zombie', 'Pablo Parés, Hernán Sáez', 1997, 'Canada'),
#  (302, 'Plaga zombie: Zona mutante', 'Pablo Parés, Hernán Sáez', 2001, 'USA'),
#  (303, 'The Plague', 'Hal Masonberg', 2006, 'Ireland'),
#  (304, 'The Plague of the Zombies', 'John Gilling', 1966, 'USA'),
#  (305, 'Plaguers', 'Brad Sykes', 2008, 'USA, UK'),
#  (306, 'Plan 9 from Outer Space', 'Edward D. Wood Jr.', 1959, 'USA'),
#  (307, 'Planet Terror', 'Robert Rodriguez', 2007, 'USA'),
#  (308, 'Pontypool', 'Bruce McDonald', 2008, 'USA'),
#  (309, 'Pop Punk Zombies', 'Steve Dayton', 2011, 'USA'),
#  (310, 'Portrait of a Zombie', 'Bing Bailey', 2012, 'USA'),
#  (311,
#   'Poultrygeist: Night of the Chicken Dead',
#   'Lloyd Kaufman',
#   2006,
#   'USA'),
#  (312, 'Pride and Prejudice and Zombies', 'Burr Steers', 2016, 'Canada'),
#  (313, 'Prince of Darkness', 'John Carpenter', 1987, 'Canada'),
#  (314, 'Pro Wrestlers vs Zombies', 'Cody Knotts', 2014, 'USA'),
#  (315, "Pushin' Up Daisies", 'Patrick Franklin', 2010, 'Germany'),
#  (316, 'Quarantine', 'John Erick Dowdle', 2008, 'South Korea'),
#  (317, 'Quarantine 2: Terminal', 'John Pogue', 2011, 'Hong Kong'),
#  (318,
#   'The Quick and the Undead',
#   'Gerald Nott',
#   2006,
#   'UK, Mexico, USA, Czech Republic'),
#  (319, 'Rabid', 'David Cronenberg', 1977, 'USA'),
#  (320, 'Rabid', 'David Cronenberg', 1977, 'Spain'),
#  (321, 'Raiders of the Living Dead', 'Samuel M. Sherman', 1986, 'San Marino'),
#  (322, 'Rammbock', 'Marvin Kren', 2010, 'Spain'),
#  (323, 'Rampant', 'Sung-hoon Kim', 2018, 'Spain'),
#  (324, 'Devil Fetus 2: The Rape After', 'Moon-Tong Lau', 1984, 'UK'),
#  (325, 'Ravenous', 'Antonia Bird', 1999, 'USA'),
#  (326, 'Re-Animator', 'Stuart Gordon', 1985, 'Canada'),
#  (327, 'REC', 'Jaume Balagueró, Paco Plaza', 2007, 'USA'),
#  (328, 'Rec 2', 'Marco Romano', 2015, 'USA'),
#  (329, '[REC] 3: Genesis', 'Paco Plaza', 2012, 'UK, Germany, France, USA'),
#  (330,
#   '[REC] 4: Apocalypse',
#   'Jaume Balagueró',
#   2014,
#   'Germany, France, USA, Canada, UK'),
#  (331,
#   'Redcon-1',
#   'Chee Keong Cheung',
#   2018,
#   'Germany, France, UK, Canada, USA'),
#  (332, 'Redneck Zombies', 'Pericles Lewnes', 1989, 'Japan'),
#  (333, 'Reel Zombies', 'David J. Francis, Mike Masters', 2008, 'Japan'),
#  (334,
#   'Reichsführer-SS',
#   'David B. Stewart III',
#   2015,
#   'France, Australia, Germany, UK, USA, Mexico, Canada'),
#  (335,
#   'Remains',
#   'Colin Theys',
#   2011,
#   'USA, Germany, France, Canada, South Africa, Australia, UK, Japan'),
#  (336,
#   'Resident Evil',
#   'Paul W.S. Anderson',
#   2002,
#   'Germany, Canada, USA, France, UK'),
#  (337, 'Resident Evil: Afterlife', 'Paul W.S. Anderson', 2010, 'Japan'),
#  (338, 'Resident Evil: Apocalypse', 'Alexander Witt', 2004, 'USA'),
#  (339, 'Resident Evil: Damnation', 'Makoto Kamiya', 2012, 'USA'),
#  (340, 'Resident Evil: Degeneration', 'Makoto Kamiya', 2008, 'USA, Romania'),
#  (341, 'Resident Evil: Extinction', 'Russell Mulcahy', 2007, 'USA, Romania'),
#  (342,
#   'Resident Evil: The Final Chapter',
#   'Paul W.S. Anderson',
#   2016,
#   'USA, United Arab Emirates'),
#  (343, 'Resident Evil: Retribution', 'Paul W.S. Anderson', 2012, 'France'),
#  (344,
#   'RESIDENT EVIL: VENDETTA',
#   'Takanori Tsujimoto',
#   2017,
#   'USA, Hong Kong, Taiwan'),
#  (345, 'The Return of the Living Dead', "Dan O'Bannon", 1985, 'USA'),
#  (346,
#   "They Won't Stay Dead: A Look at Return of the Living Dead Part II",
#   'N/A',
#   2011,
#   'USA'),
#  (347,
#   'Return of the Living Dead: Necropolis',
#   'Ellory Elkayem',
#   2005,
#   'UK, Spain, Belgium'),
#  (348,
#   'Return of the Living Dead: Rave to the Grave',
#   'Ellory Elkayem',
#   2005,
#   'USA'),
#  (349, 'The Crazies', 'Breck Eisner', 2010, 'Indonesia'),
#  (350, 'The Returned', 'N/A', 2012, 'USA'),
#  (351,
#   'The Revenge of the Living Dead Girls',
#   'Pierre B. Reinhard',
#   1987,
#   'USA'),
#  (352, 'The Revenant', 'Alejandro G. Iñárritu', 2015, 'USA'),
#  (353, 'Revenge of the Zombies', 'Steve Sekely', 1943, 'Thailand'),
#  (354, 'Revolt of the Zombies', 'Victor Halperin', 1936, 'USA'),
#  (355, 'The Rezort', 'Steve Barker', 2015, 'USA'),
#  (356, 'Rise of the Zombies', 'Nick Lyon', 2012, 'Japan'),
#  (357, 'Ritual', 'Joko Anwar', 2012, 'USA'),
#  (358, 'The Roost', 'Ti West', 2005, 'South Korea'),
#  (359, 'Route 666', 'William Wesley', 2001, 'USA'),
#  (360, 'Run! Bitch Run!', 'Joseph Guzman', 2009, 'Spain'),
#  (361, 'Sars Wars', 'Taweewat Wantha', 2004, 'USA'),
#  (362,
#   'Scary or Die',
#   'Bob Badway, Michael Emanuel, Igor Meglic',
#   2012,
#   'Hong Kong'),
#  (363,
#   'Scooby-Doo on Zombie Island',
#   'Hiroshi Aoyama, Kazumi Fukushima, Jim Stenstrum',
#   1998,
#   'USA'),
#  (364, 'School-Live!', 'N/A', 2015, 'UK, France'),
#  (365, 'Schoolgirl Apocalypse', 'John Cairns', 2011, 'UK'),
#  (366,
#   'Scouts Guide to the Zombie Apocalypse',
#   'Christopher Landon',
#   2015,
#   'USA'),
#  (367, 'Seoul Station', 'Sang-ho Yeon', 2016, 'Canada'),
#  (368, 'The Serpent and the Rainbow', 'Wes Craven', 1988, 'USA'),
#  (369, 'Sexykiller, morirás por ella', 'Miguel Martí', 2008, 'Netherlands'),
#  (370, 'Shadow: Dead Riot', 'Derek Wan', 2006, 'USA'),
#  (371, 'Shaolin vs. Evil Dead', 'Douglas Kung', 2004, 'Canada, USA'),
#  (372, 'Shatter Dead', 'Scooter McCrae', 1994, 'USA'),
#  (373, 'Shaun of the Dead', 'Edgar Wright', 2004, 'USA'),
#  (374, 'Shed of the Dead', 'Drew Cullingham', 2019, 'Australia'),
#  (375, 'Shock Waves', 'Ken Wiederhorn', 1977, 'UK'),
#  (376, 'Sick: Survive the Night', 'Ryan M. Andrews', 2012, 'UK'),
#  (377, 'Silent Night, Zombie Night', 'Sean Cain', 2009, 'USA'),
#  (378, 'Sint', 'Dick Maas', 2010, 'USA'),
#  (379, 'The Sky Has Fallen', 'Doug Roos', 2009, 'USA'),
#  (380, 'Slither', 'James Gunn', 2006, 'USA'),
#  (381, 'Special Dead', 'Thomas L. Phillips, Sean Simmons', 2006, 'USA'),
#  (382, 'Splinter', 'Toby Wilkins', 2008, 'USA, Canada'),
#  (383, 'Stacy', 'Seddon Stokes', 2013, 'USA'),
#  (384, 'Stag Night of the Dead', 'Neil Jones', 2010, 'USA'),
#  (385, 'Stalled', 'Christian James', 2013, 'USA'),
#  (386, 'State of Emergency', 'Turner Clay', 2011, 'USA'),
#  (387, 'The Stink of Flesh', 'Scott Phillips', 2005, 'Italy'),
#  (388, 'Sugar Hill', 'Leon Ichaso', 1993, 'USA'),
#  (389, 'The Supernaturals', 'Armand Mastroianni', 1986, 'South Korea, USA'),
#  (390, 'Surf II', 'Randall M. Badat', 1984, 'France'),
#  (391, 'Survival of the Dead', 'George A. Romero', 2009, 'USA'),
#  (392, 'Swamp Zombies!!!', 'Len Kabasinski', 2005, 'Japan'),
#  (393, 'Tales of Terror', 'Roger Corman', 1962, 'Spain, Portugal'),
#  (394, 'Teenage Exorcist', 'Grant Austin Waldman', 1991, 'UK'),
#  (395, 'Teenage Zombies', 'Jerry Warren', 1959, 'USA'),
#  (396, 'Terror-Creatures from the Grave', 'Massimo Pupillo', 1965, 'USA'),
#  (397, 'The Omega Man', 'Boris Sagal', 1971, 'South Korea'),
#  (398, 'The Wailing', 'Hong-jin Na', 2016, 'Philippines'),
#  (399, 'They Came Back', 'Robin Campillo', 2004, 'USA'),
#  (400, 'They Walk', 'Charles House II', 2010, 'Australia'),
#  (401, 'Tokyo Zombie', 'Sakichi Satô', 2005, 'USA'),
#  (402, 'Tombs of the Blind Dead', 'Amando de Ossorio', 1972, 'Japan'),
#  (403, 'Tormented', 'Jon Wright', 2009, 'Japan'),
#  (404, 'Toxic Zombies', 'Charles McCrann', 1980, 'USA'),
#  (405, 'Trailer Park of Terror', 'Steven Goldmann', 2008, 'USA'),
#  (406, 'Train to Busan', 'Sang-ho Yeon', 2016, 'USA'),
#  (407, 'Trip Ubusan: The Lolas vs Zombies', 'Mark A. Reyes', 2017, 'Spain'),
#  (408, 'Uncle Sam', 'William Lustig', 1996, 'Malaysia'),
#  (409, 'Undead', 'Michael Spierig, Peter Spierig', 2003, 'Japan'),
#  (410, 'Undead or Alive: A Zombedy', 'Glasgow Phillips', 2007, 'USA'),
#  (411, 'Undead Pool', 'Kôji Kawano', 2007, 'USA, Canada, Indonesia'),
#  (412, 'Uniform SurviGirl I', 'Hiroshi Kaneko', 2008, 'USA'),
#  (413, 'Urban Decay', 'Harry Basil', 2007, 'USA, Canada'),
#  (414,
#   'Valley of the Zombies',
#   'Philip Ford',
#   1946,
#   'Belgium, France, Italy, Liechtenstein'),
#  (415, 'Vampires vs. Zombies', 'Mike Goodreau', 2013, 'Germany'),
#  (416, 'Vengeance of the Zombies', 'León Klimovsky', 1973, 'USA'),
#  (417, 'Vere Vazhi Ille', 'M.S. Prem Nath', 2015, 'USA'),
#  (418, 'Versus', 'Ryûhei Kitamura', 2000, 'USA'),
#  (419,
#   'V/H/S',
#   'Matt Bettinelli-Olpin, David Bruckner, Tyler Gillett, Justin Martinez, Glenn McQuaid, Radio Silence, Joe Swanberg, Chad Villella, Ti West, Adam Wingard',
#   2012,
#   'USA'),
#  (420,
#   'V/H/S/2',
#   'Simon Barrett, Jason Eisener, Gareth Evans, Gregg Hale, Eduardo Sánchez, Timo Tjahjanto, Adam Wingard',
#   2013,
#   'USA, Lithuania, Italy'),
#  (421, 'The Video Dead', 'Robert Scott', 1987, 'USA, Canada'),
#  (422, 'The Vineyard', 'James Hong, William Rice', 1989, 'USA'),
#  (423,
#   'A Virgin Among the Living Dead',
#   'Jesús Franco, Pierre Quérut, Jean Rollin',
#   1973,
#   'USA'),
#  (424,
#   'Virus Undead',
#   'Wolf Wolff, Ohmuthi(co-director)',
#   2008,
#   'USA, West Germany, UK'),
#  (425, 'VooDoo', 'Tom Costabile', 2017, 'USA, UK'),
#  (426, 'Voodoo Dawn', 'Steven Fierberg', 1991, 'USA'),
#  (427, 'Voodoo Island', 'Reginald Le Borg', 1957, 'Denmark'),
#  (428, 'Voodoo Man', 'William Beaudine', 1944, 'USA'),
#  (429, 'War of the Dead', 'Marko Mäkilaakso', 2011, 'USA'),
#  (430, 'Warm Bodies', 'Jonathan Levine', 2013, 'Poland'),
#  (431, 'Warning Sign', 'Hal Barwood', 1985, 'Japan'),
#  (432, 'Wasting Away', 'Mitch Collier', 2009, 'UK'),
#  (433, 'Waxwork', 'Anthony Hickox', 1988, 'USA, UK, Malta'),
#  (434, 'Waxwork II: Lost in Time', 'Anthony Hickox', 1992, 'Australia'),
#  (435, "Weekend at Bernie's II", 'Robert Klane', 1993, 'Italy'),
#  (436, 'Kongefamilien på Sorgenfri Slot', 'Kaj Holbech', 1941, 'USA'),
#  (437, 'White Zombie', 'Victor Halperin', 1932, 'USA'),
#  (438, 'Wicked Little Things', 'J.S. Cardone', 2006, 'N/A'),
#  (439, 'Wilczyca', 'Marek Piestrak', 1983, 'France'),
#  (440, 'Wild Zero', 'Tetsuro Takeuchi', 1999, 'Italy'),
#  (441, 'The Woman Eater', 'Charles Saunders', 1958, 'Taiwan'),
#  (442, 'World War Z', 'Marc Forster', 2013, 'Italy'),
#  (443, 'Wyrmwood: Road of the Dead', 'Kiah Roache-Turner', 2014, 'UK, USA'),
#  (444, 'Z Island', 'N/A', 2015, 'Japan'),
#  (445, 'Zeta', 'Cosimo Alemà', 2016, 'USA'),
#  (446,
#   'ZMD: Zombies of Mass Destruction',
#   'Kevin Hamedani',
#   2009,
#   'Australia'),
#  (447, 'Zombeavers', 'Jordan Rubin', 2014, 'USA'),
#  (448, 'Papá, soy una zombi 2: Rebelión putrefacta', 'N/A', 2014, 'UK'),
#  (449, 'Zombi Child', 'Bertrand Bonello', 2019, 'Taiwan'),
#  (450, 'Zombie', 'Lucio Fulci', 1979, 'Thailand'),
#  (451, 'Zombie 108', 'Joe Chien', 2012, 'USA'),
#  (452,
#   'Zombie 5: Killing Birds',
#   "Claudio Lattanzi, Joe D'Amato",
#   1987,
#   'Italy'),
#  (453, 'Zombie Apocalypse', 'Nick Lyon', 2011, 'Italy'),
#  (454, 'Zombie Ass: The Toilet of the Dead', 'Noboru Iguchi', 2011, 'USA'),
#  (455, 'Zombie Bloodbath', 'Todd Sheets', 1993, 'USA'),
#  (456, 'Zombie Brigade', 'Carmelo Musca, Barrie Pattison', 1988, 'UK'),
#  (457, 'The Zombie Chronicles', 'Brad Sykes', 2001, 'France, Spain'),
#  (458,
#   'The Zombie Diaries',
#   'Michael G. Bartlett, Kevin Gates',
#   2006,
#   'Canada'),
#  (459, 'Zombie Fight Club', 'Joe Chien', 2014, 'USA'),
#  (460, 'Kud Krachak Krien', 'Poj Arnon', 2017, 'USA'),
#  (461, 'Zombie High', 'Ron Link', 1987, 'USA'),
#  (462, 'Zombie Holocaust', 'Marino Girolami', 1980, 'Canada'),
#  (463, 'Zombie Holocaust', 'Marino Girolami', 1980, 'Canada'),
#  (464, 'Zombie Honeymoon', 'David Gebroe', 2004, 'USA'),
#  (465, 'Zombie Hunter', 'K. King', 2013, 'Japan'),
#  (466, 'The Zombie King', 'Aidan Belizaire', 2013, 'USA'),
#  (467, 'Zombie Lake', 'Jean Rollin, Julian de Laserna', 1981, 'UK'),
#  (468, 'Zombie Massacre', 'Eric Weller', 2002, 'USA'),
#  (469, 'Zombie Nation', 'Ulli Lommel', 2004, 'USA'),
#  (470, 'Zombie Night', 'John Gulager', 2013, 'UK'),
#  (471, 'Zombie Night', 'John Gulager', 2013, 'USA'),
#  (472, 'Zombie Night 2: Awakening', 'David J. Francis', 2006, 'USA'),
#  (473, 'Zombie Nightmare', 'Jack Bravman, John Fasano', 1987, 'USA'),
#  (474, 'Zombie Planet', 'George Bonilla', 2004, 'USA'),
#  (475, 'Zombie Self-Defense Force', 'Naoyuki Tomomatsu', 2006, 'USA'),
#  (476, 'Zombie Strippers!', 'Jay Lee', 2008, 'UK'),
#  (477, 'Zombie Undead', 'Rhys Davies', 2010, 'USA'),
#  (478,
#   'Zombie! vs. Mardi Gras',
#   'Karl DeMolay, Will Frank, Mike Lyddon',
#   1999,
#   'USA'),
#  (479, 'Zombie Wars', 'David A. Prior', 2007, 'USA'),
#  (480, 'Zombie Women of Satan', "Steve O'Brien, Warren Speed", 2009, 'USA'),
#  (481, 'Zombiegeddon', 'Chris Watson', 2003, 'USA'),
#  (482, 'Zombieland', 'Ruben Fleischer', 2009, 'Hong Kong, China'),
#  (483, 'Zombieland: Double Tap', 'Ruben Fleischer', 2019, 'Singapore'),
#  (484, 'Zombies', 'Hamid Torabpour', 2017, 'Serbia, Italy, Spain'),
#  (485, 'Zombies', 'Hamid Torabpour', 2017, 'USA')]

# %%
cursor.execute("select year, count(*) from public.movies group by year order by year")
cursor.fetchall()
# Out:
# [(1932, 1),
#  (1936, 2),
#  (1940, 1),
#  (1941, 2),
#  (1942, 1),
#  (1943, 2),
#  (1944, 1),
#  (1946, 1),
#  (1955, 1),
#  (1957, 1),
#  (1958, 1),
#  (1959, 4),
#  (1961, 1),
#  (1962, 2),
#  (1963, 2),
#  (1964, 3),
#  (1965, 1),
#  (1966, 1),
#  (1968, 5),
#  (1971, 3),
#  (1972, 6),
#  (1973, 7),
#  (1974, 4),
#  (1975, 2),
#  (1977, 4),
#  (1979, 3),
#  (1980, 9),
#  (1981, 8),
#  (1982, 4),
#  (1983, 2),
#  (1984, 5),
#  (1985, 6),
#  (1986, 4),
#  (1987, 8),
#  (1988, 8),
#  (1989, 11),
#  (1990, 5),
#  (1991, 6),
#  (1992, 2),
#  (1993, 6),
#  (1994, 4),
#  (1995, 2),
#  (1996, 1),
#  (1997, 3),
#  (1998, 3),
#  (1999, 3),
#  (2000, 4),
#  (2001, 6),
#  (2002, 6),
#  (2003, 10),
#  (2004, 17),
#  (2005, 18),
#  (2006, 23),
#  (2007, 19),
#  (2008, 32),
#  (2009, 23),
#  (2010, 17),
#  (2011, 19),
#  (2012, 27),
#  (2013, 27),
#  (2014, 15),
#  (2015, 20),
#  (2016, 14),
#  (2017, 11),
#  (2018, 7),
#  (2019, 6),
#  (2020, 3)]

# %%
sql = """INSERT INTO public."movies" ("title", "gross", "location", "rating", "year", "plot") VALUES (%s,%s,%s,%s,%s,%s)"""

record = ("Test2",1000000,"Cali",10.5,2005,"Test2Plot")
cursor.execute(sql, (record))
connection.commit()
